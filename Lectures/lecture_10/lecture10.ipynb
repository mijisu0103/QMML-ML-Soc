# %%
import numpy as np
import matplotlib.pyplot as plt


import gymnasium as gym
import pygame

from typing import List
import random
from collections import deque

import torch
import torch.nn as nn
import torch.optim as optim

# %%
class Environment:
    def __init__(self):
        self.steps_left = 100
        
    def get_observation(self) -> List[float]:
        return [0.0, 0.0, 0.0]
    
    def get_actions(self) -> List[int]:
        return [0, 1]
    
    def is_done(self) -> bool:
        return self.steps_left == 0
    
    def action(self, action: int) -> float:
        
        # Handles and agents action and returns the reward
        
        if self.is_done():
            raise Exception("Game is over")
        self.steps_left -= 1
        return random.random() # Reward is random in this example

# %%
class Agent:
    def __init__(self):
        self.total_reward = 0.0
        
    def step(self, env: Environment):
        """
        Observe the environment
        Make a decision about the action to take based on the observations
        Submit the action to the environment
        Get the reward for the current step
        """
        current_obs = env.get_observation()
        actions = env.get_actions()
        reward = env.action(random.choice(actions))
        self.total_reward += reward

# %%
if __name__ == "__main__":
    env = Environment()
    agent = Agent()
    
    while not env.is_done():
        agent.step(env)
        
    print("Total reward got: %.4f" % agent.total_reward)
# Out:
# Total reward got: 47.3563

# %%
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.nn = nn.Sequential(
            nn.Linear(state_size, 128),
            nn.LayerNorm(128),
            nn.ReLU(),
            nn.Linear(128,128),
            nn.LayerNorm(128),
            nn.ReLU(),
            nn.Linear(128, action_size) # Predict Q-Values for all possible actions
        )

    def forward(self, x):
        return self.nn(x)

# %%
# Let's initialize our environment
env = gym.make("CartPole-v1")
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# Hyperparameters
batch_size = 64
gamma = 0.99           
epsilon = 1.0          
epsilon_min = 0.01
epsilon_decay = 0.99
learning_rate = 0.002
target_update_freq = 10
max_episodes = 10000

print(f"State size: {state_size}") # cart position, cart velocity, pole angle, and velocity tip of the pole.
print(f"Action size: {action_size}") # move left or move right
# Out:
# State size: 4
# Action size: 2

# %%
policy_net = DQN(state_size, action_size)
target_net = DQN(state_size, action_size)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval() # normal behaviour, no regularization (evaluation mode, no training)

optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)
loss_fn = nn.MSELoss()


memory = deque(maxlen=2000)

# %%
def remember(state, action, reward, next_state, done):
    """
    Keep different memories in buffer for sampling later.
    """
    memory.append((state, action, reward, next_state, done))

def act(state, epsilon):
    """
    Do a random action with epsilon frequency. Otherwise, do the action
    that has the maximum q_value.
    """
    if np.random.rand() <= epsilon:
        return env.action_space.sample()
    state_tensor = torch.FloatTensor(state).unsqueeze(0)
    with torch.no_grad(): # Disable gradient computation. Only need prediction here, no weights. Saves memory and is faster.
        q_values = policy_net(state_tensor) # Returns each Q-Value for each action
    return int(torch.argmax(q_values, dim=1).item()) # Select the action with the highest Q-Value

def replay():
    if len(memory) < batch_size:
        return # return nothing if we do not have enough memories in the buffer to complete one batch
    
    minibatch = random.sample(memory, batch_size) # Random sample, avoid correlation 
    states, actions, rewards, next_states, dones = zip(*minibatch)
    
    states = torch.FloatTensor(states)
    actions = torch.LongTensor(actions).unsqueeze(1) # Indexing in PyTorch requires the indices to be of the long type.
    rewards = torch.FloatTensor(rewards)
    next_states = torch.FloatTensor(next_states)
    dones = torch.FloatTensor(dones)

    # Current Q-values for the actions taken
    q_values = policy_net(states).gather(1, actions).squeeze()

    # Next state Q-values from target network
    next_q_values = target_net(next_states).max(1)[0]
    target_q_values = rewards + gamma * next_q_values * (1 - dones)

    loss = loss_fn(q_values, target_q_values)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
# Training loop with early stopping condition (average reward > 400 over last 50 episodes)
episode_rewards = []

for episode in range(1, max_episodes + 1):
    state, _ = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = act(state, epsilon)
        next_state, reward, done, truncated, _ = env.step(action)
        # Penalize if episode ends early
        reward = reward if not done else -10
        remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward
        
        replay()
        if done or truncated:
            break

    # Decay exploration rate
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

    episode_rewards.append(total_reward)
    
    # Update target network periodically
    if episode % target_update_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())

    # Check average reward over the last 50 episodes
    if len(episode_rewards) >= 50:
        avg_reward = np.mean(episode_rewards[-50:])
        print(f"Episode {episode} - Total Reward: {total_reward}, Average Reward (last 50): {avg_reward:.2f}")
        if avg_reward > 400:
            print("Training finished - average reward > 400 over the last 50 episodes")
            break
    else:
        print(f"Episode {episode} - Total Reward: {total_reward}")

env.close()
# Out:
# Episode 1 - Total Reward: 6.0
# Episode 2 - Total Reward: 4.0
# Episode 3 - Total Reward: 3.0
# Episode 4 - Total Reward: 2.0
# Episode 5 - Total Reward: 4.0
# Episode 6 - Total Reward: 0.0
# Episode 7 - Total Reward: 5.0
# Episode 8 - Total Reward: -1.0
# Episode 9 - Total Reward: 3.0
# Episode 10 - Total Reward: 1.0
# /var/folders/9c/0ymqj36s0hbd7c2g36h6ztnr0000gn/T/ipykernel_9133/1933203253.py:26: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   states = torch.FloatTensor(states)
# Episode 11 - Total Reward: 1.0
# Episode 12 - Total Reward: 15.0
# Episode 13 - Total Reward: 25.0
# Episode 14 - Total Reward: 18.0
# Episode 15 - Total Reward: 13.0
# Episode 16 - Total Reward: 1.0
# Episode 17 - Total Reward: 7.0
# Episode 18 - Total Reward: 13.0
# Episode 19 - Total Reward: 4.0
# Episode 20 - Total Reward: 12.0
# Episode 21 - Total Reward: 1.0
# Episode 22 - Total Reward: 21.0
# Episode 23 - Total Reward: 3.0
# Episode 24 - Total Reward: 5.0
# Episode 25 - Total Reward: 5.0
# Episode 26 - Total Reward: 7.0
# Episode 27 - Total Reward: 5.0
# Episode 28 - Total Reward: 12.0
# Episode 29 - Total Reward: 8.0
# Episode 30 - Total Reward: 1.0
# Episode 31 - Total Reward: 7.0
# Episode 32 - Total Reward: 9.0
# Episode 33 - Total Reward: 3.0
# Episode 34 - Total Reward: -1.0
# Episode 35 - Total Reward: 22.0
# Episode 36 - Total Reward: 2.0
# Episode 37 - Total Reward: 4.0
# Episode 38 - Total Reward: -1.0
# Episode 39 - Total Reward: 4.0
# Episode 40 - Total Reward: 8.0
# Episode 41 - Total Reward: 5.0
# Episode 42 - Total Reward: 3.0
# Episode 43 - Total Reward: 14.0
# Episode 44 - Total Reward: 23.0
# Episode 45 - Total Reward: 21.0
# Episode 46 - Total Reward: 31.0
# Episode 47 - Total Reward: 38.0
# Episode 48 - Total Reward: 6.0
# Episode 49 - Total Reward: 4.0
# Episode 50 - Total Reward: 1.0, Average Reward (last 50): 8.14
# Episode 51 - Total Reward: 14.0, Average Reward (last 50): 8.30
# Episode 52 - Total Reward: 52.0, Average Reward (last 50): 9.26
# Episode 53 - Total Reward: 43.0, Average Reward (last 50): 10.06
# Episode 54 - Total Reward: 36.0, Average Reward (last 50): 10.74
# Episode 55 - Total Reward: 1.0, Average Reward (last 50): 10.68
# Episode 56 - Total Reward: 47.0, Average Reward (last 50): 11.62
# Episode 57 - Total Reward: 30.0, Average Reward (last 50): 12.12
# Episode 58 - Total Reward: 29.0, Average Reward (last 50): 12.72
# Episode 59 - Total Reward: 15.0, Average Reward (last 50): 12.96
# Episode 60 - Total Reward: 3.0, Average Reward (last 50): 13.00
# Episode 61 - Total Reward: 66.0, Average Reward (last 50): 14.30
# Episode 62 - Total Reward: 9.0, Average Reward (last 50): 14.18
# Episode 63 - Total Reward: 15.0, Average Reward (last 50): 13.98
# Episode 64 - Total Reward: 49.0, Average Reward (last 50): 14.60
# Episode 65 - Total Reward: 55.0, Average Reward (last 50): 15.44
# Episode 66 - Total Reward: 29.0, Average Reward (last 50): 16.00
# Episode 67 - Total Reward: 27.0, Average Reward (last 50): 16.40
# Episode 68 - Total Reward: 97.0, Average Reward (last 50): 18.08
# Episode 69 - Total Reward: 116.0, Average Reward (last 50): 20.32
# Episode 70 - Total Reward: 41.0, Average Reward (last 50): 20.90
# Episode 71 - Total Reward: 3.0, Average Reward (last 50): 20.94
# Episode 72 - Total Reward: 9.0, Average Reward (last 50): 20.70
# Episode 73 - Total Reward: 3.0, Average Reward (last 50): 20.70
# Episode 74 - Total Reward: 44.0, Average Reward (last 50): 21.48
# Episode 75 - Total Reward: 25.0, Average Reward (last 50): 21.88
# Episode 76 - Total Reward: 25.0, Average Reward (last 50): 22.24
# Episode 77 - Total Reward: 49.0, Average Reward (last 50): 23.12
# Episode 78 - Total Reward: 6.0, Average Reward (last 50): 23.00
# Episode 79 - Total Reward: 78.0, Average Reward (last 50): 24.40
# Episode 80 - Total Reward: 18.0, Average Reward (last 50): 24.74
# Episode 81 - Total Reward: 19.0, Average Reward (last 50): 24.98
# Episode 82 - Total Reward: 43.0, Average Reward (last 50): 25.66
# Episode 83 - Total Reward: 51.0, Average Reward (last 50): 26.62
# Episode 84 - Total Reward: 117.0, Average Reward (last 50): 28.98
# Episode 85 - Total Reward: 53.0, Average Reward (last 50): 29.60
# Episode 86 - Total Reward: 15.0, Average Reward (last 50): 29.86
# Episode 87 - Total Reward: 67.0, Average Reward (last 50): 31.12
# Episode 88 - Total Reward: 10.0, Average Reward (last 50): 31.34
# Episode 89 - Total Reward: 69.0, Average Reward (last 50): 32.64
# Episode 90 - Total Reward: 107.0, Average Reward (last 50): 34.62
# Episode 91 - Total Reward: 37.0, Average Reward (last 50): 35.26
# Episode 92 - Total Reward: 0.0, Average Reward (last 50): 35.20
# Episode 93 - Total Reward: 51.0, Average Reward (last 50): 35.94
# Episode 94 - Total Reward: 79.0, Average Reward (last 50): 37.06
# Episode 95 - Total Reward: 157.0, Average Reward (last 50): 39.78
# Episode 279 - Total Reward: 287.0, Average Reward (last 50): 254.40
# Episode 280 - Total Reward: 221.0, Average Reward (last 50): 254.54
# Episode 281 - Total Reward: 500.0, Average Reward (last 50): 263.10
# Episode 282 - Total Reward: 500.0, Average Reward (last 50): 273.08
# Episode 283 - Total Reward: 500.0, Average Reward (last 50): 282.90
# Episode 284 - Total Reward: 500.0, Average Reward (last 50): 282.90
# Episode 285 - Total Reward: 500.0, Average Reward (last 50): 282.90
# Episode 286 - Total Reward: 500.0, Average Reward (last 50): 285.20
# Episode 287 - Total Reward: 500.0, Average Reward (last 50): 285.20
# Episode 288 - Total Reward: 500.0, Average Reward (last 50): 285.20
# Episode 289 - Total Reward: 500.0, Average Reward (last 50): 285.20
# Episode 290 - Total Reward: 500.0, Average Reward (last 50): 285.20
# Episode 291 - Total Reward: 500.0, Average Reward (last 50): 285.20
# Episode 292 - Total Reward: 52.0, Average Reward (last 50): 276.24
# Episode 293 - Total Reward: 6.0, Average Reward (last 50): 266.36
# Episode 294 - Total Reward: 7.0, Average Reward (last 50): 256.50
# Episode 295 - Total Reward: 8.0, Average Reward (last 50): 246.66
# Episode 296 - Total Reward: 27.0, Average Reward (last 50): 247.20
# Episode 297 - Total Reward: 58.0, Average Reward (last 50): 247.56
# Episode 298 - Total Reward: 19.0, Average Reward (last 50): 247.96
# Episode 299 - Total Reward: 8.0, Average Reward (last 50): 248.16
# Episode 300 - Total Reward: 37.0, Average Reward (last 50): 248.96
# Episode 301 - Total Reward: 5.0, Average Reward (last 50): 240.78
# Episode 302 - Total Reward: -2.0, Average Reward (last 50): 237.26
# Episode 303 - Total Reward: 500.0, Average Reward (last 50): 240.56
# Episode 304 - Total Reward: 290.0, Average Reward (last 50): 242.18
# Episode 305 - Total Reward: 88.0, Average Reward (last 50): 240.34
# Episode 306 - Total Reward: 219.0, Average Reward (last 50): 240.00
# Episode 307 - Total Reward: 338.0, Average Reward (last 50): 241.32
# Episode 308 - Total Reward: 64.0, Average Reward (last 50): 239.40
# Episode 309 - Total Reward: 247.0, Average Reward (last 50): 240.24
# Episode 310 - Total Reward: 396.0, Average Reward (last 50): 244.16
# Episode 311 - Total Reward: 500.0, Average Reward (last 50): 250.68
# Episode 312 - Total Reward: 208.0, Average Reward (last 50): 253.54
# Episode 313 - Total Reward: 102.0, Average Reward (last 50): 251.70
# Episode 314 - Total Reward: 173.0, Average Reward (last 50): 252.18
# Episode 315 - Total Reward: 500.0, Average Reward (last 50): 260.84
# Episode 316 - Total Reward: 345.0, Average Reward (last 50): 265.08
# Episode 317 - Total Reward: 500.0, Average Reward (last 50): 272.34
# Episode 318 - Total Reward: 500.0, Average Reward (last 50): 279.18
# Episode 319 - Total Reward: 318.0, Average Reward (last 50): 282.30
# Episode 320 - Total Reward: 500.0, Average Reward (last 50): 288.92
# Episode 321 - Total Reward: 500.0, Average Reward (last 50): 294.18
# Episode 322 - Total Reward: 500.0, Average Reward (last 50): 294.18
# Episode 323 - Total Reward: 500.0, Average Reward (last 50): 294.18
# Episode 324 - Total Reward: 500.0, Average Reward (last 50): 298.22
# Episode 325 - Total Reward: 500.0, Average Reward (last 50): 303.80
# Episode 326 - Total Reward: 500.0, Average Reward (last 50): 308.82
# Episode 327 - Total Reward: 500.0, Average Reward (last 50): 315.50
# Episode 328 - Total Reward: 500.0, Average Reward (last 50): 320.42
# Episode 329 - Total Reward: 500.0, Average Reward (last 50): 324.68
# Episode 330 - Total Reward: 500.0, Average Reward (last 50): 330.26
# Episode 331 - Total Reward: 500.0, Average Reward (last 50): 330.26
# Episode 332 - Total Reward: 500.0, Average Reward (last 50): 330.26
# Episode 333 - Total Reward: 500.0, Average Reward (last 50): 330.26
# Episode 334 - Total Reward: 81.0, Average Reward (last 50): 321.88
# Episode 335 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 336 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 337 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 338 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 339 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 340 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 341 - Total Reward: 500.0, Average Reward (last 50): 321.88
# Episode 342 - Total Reward: 500.0, Average Reward (last 50): 330.84
# Episode 343 - Total Reward: 500.0, Average Reward (last 50): 340.72
# Episode 344 - Total Reward: 500.0, Average Reward (last 50): 350.58
# Episode 345 - Total Reward: 500.0, Average Reward (last 50): 360.42
# Episode 346 - Total Reward: 500.0, Average Reward (last 50): 369.88
# Episode 347 - Total Reward: 500.0, Average Reward (last 50): 378.72
# Episode 348 - Total Reward: 500.0, Average Reward (last 50): 388.34
# Episode 349 - Total Reward: 500.0, Average Reward (last 50): 398.18
# Episode 350 - Total Reward: 500.0, Average Reward (last 50): 407.44
# Training finished - average reward > 400 over the last 50 episodes

# %%
# Plot total rewards per episode and the moving average over the last 50 episodes
episodes = range(1, len(episode_rewards) + 1)
window = 50
moving_avg = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')

plt.figure(figsize=(10, 5))
plt.plot(episodes, episode_rewards, label="Total Reward per Episode")
plt.plot(range(window, len(episode_rewards) + 1), moving_avg, label="Moving Average (Last 50 Episodes)", linewidth=3)
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Training Progress: Total Rewards and Moving Average")
plt.legend()
plt.show()

# %%
# After training, create a new environment with rendering enabled
play_env = gym.make("CartPole-v1", render_mode="human")
state, _ = play_env.reset()
done = False
total_reward = 0

while not done:
    action = act(state, epsilon=0.0)  # Use greedy action (no exploration)
    state, reward, done, truncated, _ = play_env.step(action)
    total_reward += reward
    play_env.render()  # Display the animation frame by frame
    if done or truncated:
        break

print(f"Final run total reward: {total_reward}")

try:
    env.close()
except Exception as e:
    print("Error closing environment:", e)
    pygame.display.quit()
    pygame.quit()
# Out:
# 2025-04-07 11:21:03.170 python[9133:135397] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-04-07 11:21:03.170 python[9133:135397] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Final run total reward: 500.0

# %% [markdown]
# ### Question 1:
# After this tutorial, your current goal now is to achieve a higher reward in the CartPole environment using the Deep Q-Network (DQN). Modify the training code so that the agent achieves an **average reward of 450 over the last 100 observations**. You may consider adjusting the learning rate, gamma, introducing an alpha value (see notes) or changing the architecture of the NN (Layers, Regularization, Neurons, etc). You can also experiment with changing the epsilon schedule (exploration/exploitation balance). Try and do it in the minumum number of Episodes possible (max 10,000).

# %%
# Hyperparameters
batch_size = 64
gamma = 0.995
epsilon = 1.0
epsilon_min = 0.01
epsilon_decay = 0.99
learning_rate = 0.005
target_update_freq = 5
max_episodes = 10000
alpha = 0.005  

# Soft update function
def soft_update(target_net, policy_net, alpha):
    for target_param, policy_param in zip(target_net.parameters(), policy_net.parameters()):
        target_param.data.copy_((1.0 - alpha) * target_param.data + alpha * policy_param.data)

# Training loop with early stopping condition (average reward > 450 over last 100 episodes)
episode_rewards = []

for episode in range(1, max_episodes + 1):
    state, _ = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = act(state, epsilon)
        next_state, reward, done, truncated, _ = env.step(action)

        # Penalise if episode ends early
        reward = reward if not done else -10
        remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        replay()
        if done or truncated:
            break

    # Decay exploration rate
    if epsilon > epsilon_min:
        epsilon *= epsilon_decay

    episode_rewards.append(total_reward)

    # Apply soft target update periodically
    if episode % target_update_freq == 0:
        soft_update(target_net, policy_net, alpha)

    # Print progress and early stop condition
    if len(episode_rewards) >= 100:
        avg_reward = np.mean(episode_rewards[-100:])
        print(f"Episode {episode} - Total Reward: {total_reward}, Average Reward (last 100): {avg_reward:.2f}")
        if avg_reward > 450:
            print("Training finished - average reward > 450 over the last 100 episodes")
            break
    else:
        print(f"Episode {episode} - Total Reward: {total_reward}")

env.close()
# Out:
# Episode 1 - Total Reward: -1.0
# Episode 2 - Total Reward: 23.0
# Episode 3 - Total Reward: 18.0
# Episode 4 - Total Reward: 12.0
# Episode 5 - Total Reward: 3.0
# Episode 6 - Total Reward: 6.0
# Episode 7 - Total Reward: 3.0
# Episode 8 - Total Reward: 2.0
# Episode 9 - Total Reward: 6.0
# Episode 10 - Total Reward: 5.0
# Episode 11 - Total Reward: 4.0
# Episode 12 - Total Reward: 60.0
# Episode 13 - Total Reward: 0.0
# Episode 14 - Total Reward: 16.0
# Episode 15 - Total Reward: 39.0
# Episode 16 - Total Reward: 8.0
# Episode 17 - Total Reward: 15.0
# Episode 18 - Total Reward: -1.0
# Episode 19 - Total Reward: 71.0
# Episode 20 - Total Reward: 7.0
# Episode 21 - Total Reward: 19.0
# Episode 22 - Total Reward: 25.0
# Episode 23 - Total Reward: 39.0
# Episode 24 - Total Reward: 22.0
# Episode 25 - Total Reward: 46.0
# Episode 26 - Total Reward: 24.0
# Episode 27 - Total Reward: 32.0
# Episode 28 - Total Reward: 19.0
# Episode 29 - Total Reward: 15.0
# Episode 30 - Total Reward: 23.0
# Episode 31 - Total Reward: 66.0
# Episode 32 - Total Reward: 23.0
# Episode 33 - Total Reward: 29.0
# Episode 34 - Total Reward: 26.0
# Episode 35 - Total Reward: 122.0
# Episode 36 - Total Reward: 70.0
# Episode 37 - Total Reward: 7.0
# Episode 38 - Total Reward: 5.0
# Episode 39 - Total Reward: 23.0
# Episode 40 - Total Reward: 17.0
# Episode 41 - Total Reward: 9.0
# Episode 42 - Total Reward: 31.0
# Episode 43 - Total Reward: 70.0
# Episode 44 - Total Reward: 30.0
# Episode 115 - Total Reward: 366.0, Average Reward (last 100): 123.28
# Episode 116 - Total Reward: 203.0, Average Reward (last 100): 125.23
# Episode 117 - Total Reward: 405.0, Average Reward (last 100): 129.13
# Episode 118 - Total Reward: 327.0, Average Reward (last 100): 132.41
# Episode 119 - Total Reward: 500.0, Average Reward (last 100): 136.70
# Episode 120 - Total Reward: 58.0, Average Reward (last 100): 137.21
# Episode 121 - Total Reward: 500.0, Average Reward (last 100): 142.02
# Episode 122 - Total Reward: 500.0, Average Reward (last 100): 146.77
# Episode 123 - Total Reward: 425.0, Average Reward (last 100): 150.63
# Episode 124 - Total Reward: 110.0, Average Reward (last 100): 151.51
# Episode 125 - Total Reward: 336.0, Average Reward (last 100): 154.41
# Episode 126 - Total Reward: 372.0, Average Reward (last 100): 157.89
# Episode 127 - Total Reward: 500.0, Average Reward (last 100): 162.57
# Episode 128 - Total Reward: 31.0, Average Reward (last 100): 162.69
# Episode 129 - Total Reward: 158.0, Average Reward (last 100): 164.12
# Episode 130 - Total Reward: 35.0, Average Reward (last 100): 164.24
# Episode 131 - Total Reward: 353.0, Average Reward (last 100): 167.11
# Episode 132 - Total Reward: 78.0, Average Reward (last 100): 167.66
# Episode 133 - Total Reward: 137.0, Average Reward (last 100): 168.74
# Episode 134 - Total Reward: 359.0, Average Reward (last 100): 172.07
# Episode 135 - Total Reward: 213.0, Average Reward (last 100): 172.98
# Episode 136 - Total Reward: 263.0, Average Reward (last 100): 174.91
# Episode 137 - Total Reward: 375.0, Average Reward (last 100): 178.59
# Episode 138 - Total Reward: 427.0, Average Reward (last 100): 182.81
# Episode 139 - Total Reward: 56.0, Average Reward (last 100): 183.14
# Episode 140 - Total Reward: 122.0, Average Reward (last 100): 184.19
# Episode 141 - Total Reward: 334.0, Average Reward (last 100): 187.44
# Episode 142 - Total Reward: 500.0, Average Reward (last 100): 192.13
# Episode 143 - Total Reward: 376.0, Average Reward (last 100): 195.19
# Episode 144 - Total Reward: 500.0, Average Reward (last 100): 199.89
# Episode 145 - Total Reward: 500.0, Average Reward (last 100): 204.70
# Episode 146 - Total Reward: 500.0, Average Reward (last 100): 209.65
# Episode 147 - Total Reward: 243.0, Average Reward (last 100): 211.61
# Episode 148 - Total Reward: 500.0, Average Reward (last 100): 216.15
# Episode 149 - Total Reward: 458.0, Average Reward (last 100): 220.68
# Episode 150 - Total Reward: 286.0, Average Reward (last 100): 222.40
# Episode 151 - Total Reward: 193.0, Average Reward (last 100): 224.17
# Episode 152 - Total Reward: 500.0, Average Reward (last 100): 228.45
# Episode 153 - Total Reward: 500.0, Average Reward (last 100): 231.46
# Episode 154 - Total Reward: 500.0, Average Reward (last 100): 235.66
# Episode 155 - Total Reward: 398.0, Average Reward (last 100): 237.76
# Episode 156 - Total Reward: 500.0, Average Reward (last 100): 242.12
# Episode 157 - Total Reward: 500.0, Average Reward (last 100): 247.07
# Episode 158 - Total Reward: 500.0, Average Reward (last 100): 250.64
# Episode 159 - Total Reward: 500.0, Average Reward (last 100): 254.76
# Episode 160 - Total Reward: 414.0, Average Reward (last 100): 258.34
# Episode 161 - Total Reward: 350.0, Average Reward (last 100): 260.98
# Episode 162 - Total Reward: 420.0, Average Reward (last 100): 263.69
# Episode 163 - Total Reward: 500.0, Average Reward (last 100): 266.91
# Episode 164 - Total Reward: 352.0, Average Reward (last 100): 270.21
# Episode 165 - Total Reward: 392.0, Average Reward (last 100): 273.58
# Episode 166 - Total Reward: 240.0, Average Reward (last 100): 275.43
# Episode 167 - Total Reward: 500.0, Average Reward (last 100): 279.71
# Episode 168 - Total Reward: 500.0, Average Reward (last 100): 284.00
# Episode 169 - Total Reward: 117.0, Average Reward (last 100): 285.03
# Episode 170 - Total Reward: 413.0, Average Reward (last 100): 288.77
# Episode 171 - Total Reward: 500.0, Average Reward (last 100): 291.60
# Episode 172 - Total Reward: 416.0, Average Reward (last 100): 294.38
# Episode 173 - Total Reward: 359.0, Average Reward (last 100): 297.26
# Episode 174 - Total Reward: 440.0, Average Reward (last 100): 300.26
# Episode 175 - Total Reward: 500.0, Average Reward (last 100): 304.26
# Episode 176 - Total Reward: 424.0, Average Reward (last 100): 306.18
# Episode 177 - Total Reward: 500.0, Average Reward (last 100): 310.64
# Episode 178 - Total Reward: 436.0, Average Reward (last 100): 312.52
# Episode 179 - Total Reward: 424.0, Average Reward (last 100): 316.16
# Episode 180 - Total Reward: 500.0, Average Reward (last 100): 317.66
# Episode 181 - Total Reward: 467.0, Average Reward (last 100): 321.32
# Episode 182 - Total Reward: 500.0, Average Reward (last 100): 325.87
# Episode 183 - Total Reward: 93.0, Average Reward (last 100): 321.80
# Episode 184 - Total Reward: 252.0, Average Reward (last 100): 319.32
# Episode 185 - Total Reward: 61.0, Average Reward (last 100): 319.22
# Episode 186 - Total Reward: 76.0, Average Reward (last 100): 318.02
# Episode 187 - Total Reward: 235.0, Average Reward (last 100): 319.32
# Episode 188 - Total Reward: 255.0, Average Reward (last 100): 319.80
# Episode 189 - Total Reward: 355.0, Average Reward (last 100): 320.32
# Episode 190 - Total Reward: 357.0, Average Reward (last 100): 323.38
# Episode 191 - Total Reward: 500.0, Average Reward (last 100): 325.65
# Episode 192 - Total Reward: 500.0, Average Reward (last 100): 330.60
# Episode 193 - Total Reward: 500.0, Average Reward (last 100): 333.61
# Episode 194 - Total Reward: 500.0, Average Reward (last 100): 337.16
# Episode 195 - Total Reward: 422.0, Average Reward (last 100): 337.90
# Episode 196 - Total Reward: 500.0, Average Reward (last 100): 340.58
# Episode 197 - Total Reward: 500.0, Average Reward (last 100): 343.11
# Episode 198 - Total Reward: 500.0, Average Reward (last 100): 348.09
# Episode 199 - Total Reward: 500.0, Average Reward (last 100): 352.68
# Episode 200 - Total Reward: 500.0, Average Reward (last 100): 355.99
# Episode 201 - Total Reward: 415.0, Average Reward (last 100): 359.17
# Episode 202 - Total Reward: 358.0, Average Reward (last 100): 361.04
# Episode 203 - Total Reward: 188.0, Average Reward (last 100): 357.92
# Episode 204 - Total Reward: 468.0, Average Reward (last 100): 357.60
# Episode 205 - Total Reward: 462.0, Average Reward (last 100): 358.41
# Episode 206 - Total Reward: 327.0, Average Reward (last 100): 359.33
# Episode 207 - Total Reward: 500.0, Average Reward (last 100): 363.02
# Episode 208 - Total Reward: 308.0, Average Reward (last 100): 365.81
# Episode 209 - Total Reward: 266.0, Average Reward (last 100): 363.47
# Episode 210 - Total Reward: 295.0, Average Reward (last 100): 364.31
# Episode 211 - Total Reward: 362.0, Average Reward (last 100): 367.08
# Episode 212 - Total Reward: 349.0, Average Reward (last 100): 369.53
# Episode 213 - Total Reward: 307.0, Average Reward (last 100): 368.72
# Episode 214 - Total Reward: 200.0, Average Reward (last 100): 365.72
# Episode 215 - Total Reward: 500.0, Average Reward (last 100): 367.06
# Episode 216 - Total Reward: 373.0, Average Reward (last 100): 368.76
# Episode 217 - Total Reward: 500.0, Average Reward (last 100): 369.71
# Episode 218 - Total Reward: 500.0, Average Reward (last 100): 371.44
# Episode 219 - Total Reward: 500.0, Average Reward (last 100): 371.44
# Episode 220 - Total Reward: 500.0, Average Reward (last 100): 375.86
# Episode 221 - Total Reward: 429.0, Average Reward (last 100): 375.15
# Episode 222 - Total Reward: 409.0, Average Reward (last 100): 374.24
# Episode 223 - Total Reward: 395.0, Average Reward (last 100): 373.94
# Episode 224 - Total Reward: 476.0, Average Reward (last 100): 377.60
# Episode 225 - Total Reward: 298.0, Average Reward (last 100): 377.22
# Episode 226 - Total Reward: 380.0, Average Reward (last 100): 377.30
# Episode 227 - Total Reward: 111.0, Average Reward (last 100): 373.41
# Episode 228 - Total Reward: 500.0, Average Reward (last 100): 378.10
# Episode 229 - Total Reward: 500.0, Average Reward (last 100): 381.52
# Episode 230 - Total Reward: 500.0, Average Reward (last 100): 386.17
# Episode 231 - Total Reward: 500.0, Average Reward (last 100): 387.64
# Episode 232 - Total Reward: 472.0, Average Reward (last 100): 391.58
# Episode 233 - Total Reward: 500.0, Average Reward (last 100): 395.21
# Episode 234 - Total Reward: 476.0, Average Reward (last 100): 396.38
# Episode 235 - Total Reward: 500.0, Average Reward (last 100): 399.25
# Episode 236 - Total Reward: 401.0, Average Reward (last 100): 400.63
# Episode 237 - Total Reward: 448.0, Average Reward (last 100): 401.36
# Episode 238 - Total Reward: 482.0, Average Reward (last 100): 401.91
# Episode 239 - Total Reward: 500.0, Average Reward (last 100): 406.35
# Episode 240 - Total Reward: 500.0, Average Reward (last 100): 410.13
# Episode 241 - Total Reward: 500.0, Average Reward (last 100): 411.79
# Episode 242 - Total Reward: 378.0, Average Reward (last 100): 410.57
# Episode 243 - Total Reward: 457.0, Average Reward (last 100): 411.38
# Episode 244 - Total Reward: 500.0, Average Reward (last 100): 411.38
# Episode 245 - Total Reward: 465.0, Average Reward (last 100): 411.03
# Episode 246 - Total Reward: 500.0, Average Reward (last 100): 411.03
# Episode 247 - Total Reward: 500.0, Average Reward (last 100): 413.60
# Episode 248 - Total Reward: 500.0, Average Reward (last 100): 413.60
# Episode 249 - Total Reward: 393.0, Average Reward (last 100): 412.95
# Episode 250 - Total Reward: 396.0, Average Reward (last 100): 414.05
# Episode 251 - Total Reward: 337.0, Average Reward (last 100): 415.49
# Episode 252 - Total Reward: 464.0, Average Reward (last 100): 415.13
# Episode 253 - Total Reward: 406.0, Average Reward (last 100): 414.19
# Episode 254 - Total Reward: 465.0, Average Reward (last 100): 413.84
# Episode 255 - Total Reward: 445.0, Average Reward (last 100): 414.31
# Episode 256 - Total Reward: 282.0, Average Reward (last 100): 412.13
# Episode 257 - Total Reward: 464.0, Average Reward (last 100): 411.77
# Episode 258 - Total Reward: 441.0, Average Reward (last 100): 411.18
# Episode 259 - Total Reward: 500.0, Average Reward (last 100): 411.18
# Episode 260 - Total Reward: 402.0, Average Reward (last 100): 411.06
# Episode 261 - Total Reward: 468.0, Average Reward (last 100): 412.24
# Episode 262 - Total Reward: 448.0, Average Reward (last 100): 412.52
# Episode 263 - Total Reward: 433.0, Average Reward (last 100): 411.85
# Episode 264 - Total Reward: 500.0, Average Reward (last 100): 413.33
# Episode 265 - Total Reward: 500.0, Average Reward (last 100): 414.41
# Episode 266 - Total Reward: 500.0, Average Reward (last 100): 417.01
# Episode 267 - Total Reward: 500.0, Average Reward (last 100): 417.01
# Episode 268 - Total Reward: 500.0, Average Reward (last 100): 417.01
# Episode 269 - Total Reward: 500.0, Average Reward (last 100): 420.84
# Episode 270 - Total Reward: 500.0, Average Reward (last 100): 421.71
# Episode 271 - Total Reward: 500.0, Average Reward (last 100): 421.71
# Episode 272 - Total Reward: 500.0, Average Reward (last 100): 422.55
# Episode 273 - Total Reward: 500.0, Average Reward (last 100): 423.96
# Episode 274 - Total Reward: 500.0, Average Reward (last 100): 424.56
# Episode 275 - Total Reward: 500.0, Average Reward (last 100): 424.56
# Episode 276 - Total Reward: 500.0, Average Reward (last 100): 425.32
# Episode 277 - Total Reward: 500.0, Average Reward (last 100): 425.32
# Episode 278 - Total Reward: 500.0, Average Reward (last 100): 425.96
# Episode 279 - Total Reward: 500.0, Average Reward (last 100): 426.72
# Episode 280 - Total Reward: 500.0, Average Reward (last 100): 426.72
# Episode 281 - Total Reward: 500.0, Average Reward (last 100): 427.05
# Episode 282 - Total Reward: 500.0, Average Reward (last 100): 427.05
# Episode 283 - Total Reward: 500.0, Average Reward (last 100): 431.12
# Episode 284 - Total Reward: 500.0, Average Reward (last 100): 433.60
# Episode 285 - Total Reward: 500.0, Average Reward (last 100): 437.99
# Episode 286 - Total Reward: 500.0, Average Reward (last 100): 442.23
# Episode 287 - Total Reward: 500.0, Average Reward (last 100): 444.88
# Episode 288 - Total Reward: 500.0, Average Reward (last 100): 447.33
# Episode 289 - Total Reward: 500.0, Average Reward (last 100): 448.78
# Episode 290 - Total Reward: 500.0, Average Reward (last 100): 450.21
# Training finished - average reward > 450 over the last 100 episodes

# %%
# Plot total rewards per episode and the moving average over the last 100 episodes
episodes = range(1, len(episode_rewards) + 1)
window = 100
moving_avg = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')

plt.figure(figsize=(10, 5))
plt.plot(episodes, episode_rewards, label="Total Reward per Episode")
plt.plot(range(window, len(episode_rewards) + 1), moving_avg, label="Moving Average (Last 100 Episodes)", linewidth=3)
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Training Progress: Total Rewards and Moving Average")
plt.legend()
plt.show()
